# %% [markdown]
# <a href="https://colab.research.google.com/github/UPM-UNI/O365-EDU-Tools/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import Libraries

# %%
from keras.layers import Dense, Dropout, Flatten
from keras.models import Sequential
from keras.layers.convolutional import Conv2D ,MaxPooling2D
from keras.optimizers import Adam
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import pickle
import pandas as pd
import numpy as np
import random

# %% [markdown]
# Import Dataset and Explore it

# %%
# cloning repo containing the traffic sign dataset
# !git clone https://bitbucket.org/jadslim/german-traffic-signs
# Out:
# fatal: destination path 'german-traffic-signs' already exists and is not an empty directory.

# %%
# list dataset contents
# !ls german-traffic-signs
# Out:
# signnames.csv  test.p  train.p	valid.p

# %%
#load the dataset
data = pd.read_csv('german-traffic-signs/signnames.csv')

# %%
data
# Out:
#     ClassId                                           SignName
# 0         0                               Speed limit (20km/h)
# 1         1                               Speed limit (30km/h)
# 2         2                               Speed limit (50km/h)
# 3         3                               Speed limit (60km/h)
# 4         4                               Speed limit (70km/h)
# 5         5                               Speed limit (80km/h)
# 6         6                        End of speed limit (80km/h)
# 7         7                              Speed limit (100km/h)
# 8         8                              Speed limit (120km/h)
# 9         9                                         No passing
# 10       10       No passing for vechiles over 3.5 metric tons
# 11       11              Right-of-way at the next intersection
# 12       12                                      Priority road
# 13       13                                              Yield
# 14       14                                               Stop
# 15       15                                        No vechiles
# 16       16           Vechiles over 3.5 metric tons prohibited
# 17       17                                           No entry
# 18       18                                    General caution
# 19       19                        Dangerous curve to the left
# 20       20                       Dangerous curve to the right
# 21       21                                       Double curve
# 22       22                                         Bumpy road
# 23       23                                      Slippery road
# 24       24                          Road narrows on the right
# 25       25                                          Road work
# 26       26                                    Traffic signals
# 27       27                                        Pedestrians
# 28       28                                  Children crossing
# 29       29                                  Bicycles crossing
# 30       30                                 Beware of ice/snow
# 31       31                              Wild animals crossing
# 32       32                End of all speed and passing limits
# 33       33                                   Turn right ahead
# 34       34                                    Turn left ahead
# 35       35                                         Ahead only
# 36       36                               Go straight or right
# 37       37                                Go straight or left
# 38       38                                         Keep right
# 39       39                                          Keep left
# 40       40                               Roundabout mandatory
# 41       41                                  End of no passing
# 42       42  End of no passing by vechiles over 3.5 metric ...

# %%
#loading pickled dataset
with open("german-traffic-signs/train.p" ,mode='rb') as training:
  train = pickle.load(training)

  with open("german-traffic-signs/valid.p" ,mode='rb') as validation:
    valid = pickle.load(validation)
    with open("german-traffic-signs/test.p" ,mode='rb') as testing:
      test =pickle.load(testing)

# %%
X_train ,y_train = train['features'], train['labels']
X_validation , y_validation = valid['features'], valid['labels']
X_test , y_test = test['features'], test['labels']

# %%
print(X_train.shape)
print(X_validation.shape)
print(X_test.shape)
# Out:
# (34799, 32, 32, 3)
# (4410, 32, 32, 3)
# (12630, 32, 32, 3)

# %%
index = np.random.randint(1,len(X_train))
plt.imshow(X_train[index])
print("image label={}".format(y_train[index]))
# Out:
# image label=21

# %%
# shuffle the data
from sklearn.utils import shuffle
X_train , y_train = shuffle(X_train,y_train)

# %%
def preprocessing(img):
  #convert to grayscale
  img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
  #Applying histogram
  img = cv2.equalizeHist(img)
  #Normalization
  img = img/255
  return img

# %%
X_train_processed = np.array(list(map(preprocessing,X_train)))
X_test_processed = np.array(list(map(preprocessing,X_test)))
X_validation_processed = np.array(list(map(preprocessing,X_validation)))

# %%
X_train_processed = X_train_processed.reshape(34799,32,32,1)
X_test_processed = X_test_processed.reshape(12630,32,32,1)
X_validation_processed = X_validation_processed.reshape(4410,32,32,1)

# %%
print(X_train_processed.shape)
print(X_test_processed.shape)
print(X_validation_processed.shape)
# Out:
# (34799, 32, 32, 1)
# (12630, 32, 32, 1)
# (4410, 32, 32, 1)

# %%
i= random.randint(1,len(X_train))
plt.imshow(X_train_processed[i].squeeze(),cmap='gray')
plt.figure()
plt.imshow(X_train[i].squeeze())

# %%
model = Sequential()
#add the convolutionnal layer
#filters, size of filters,input_shape,activation_function
model.add(Conv2D(32,(5,5),activation='relu',input_shape=(32,32,1)))

#pooling layer
model.add(MaxPooling2D(pool_size=(2,2)))

#place a dropout layer
model.add(Dropout(0.25))

#add another convlutional layer
model.add(Conv2D(64,(5,5),activation='relu'))

#pooling layer
model.add(MaxPooling2D(pool_size=(2,2)))

#flatten the image to 1 dimensional array
model.add(Flatten())

#add a dense layer : amount of nodes, activation
model.add(Dense(256,activation='relu'))

#place a dropout layer
#0.5 drop out rate is recommended, half input nodes will be dropped at each update
model.add(Dropout(0.5))

#defining the output layer of our network
model.add(Dense(43,activation='softmax'))

model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 28, 28, 32)        832
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 10, 10, 64)        51264
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               409856
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 43)                11051
# =================================================================
# Total params: 473,003
# Trainable params: 473,003
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile our model
model.compile(Adam(lr=0.0001),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X_train_processed,y_train,batch_size=500,epochs=50,verbose=1,validation_data=(X_validation_processed,y_validation))
# Out:
# Train on 34799 samples, validate on 4410 samples
# Epoch 1/50
# 34799/34799 [==============================] - 7s 203us/step - loss: 3.5590 - accuracy: 0.0659 - val_loss: 3.4719 - val_accuracy: 0.1771
# Epoch 2/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 3.2644 - accuracy: 0.1720 - val_loss: 3.0348 - val_accuracy: 0.3283
# Epoch 3/50
# 34799/34799 [==============================] - 1s 22us/step - loss: 2.6866 - accuracy: 0.3274 - val_loss: 2.3706 - val_accuracy: 0.4361
# Epoch 4/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 2.1571 - accuracy: 0.4300 - val_loss: 1.8892 - val_accuracy: 0.5018
# Epoch 5/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 1.8089 - accuracy: 0.5011 - val_loss: 1.5634 - val_accuracy: 0.5778
# Epoch 6/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 1.5607 - accuracy: 0.5577 - val_loss: 1.3090 - val_accuracy: 0.6481
# Epoch 7/50
# 34799/34799 [==============================] - 1s 22us/step - loss: 1.3746 - accuracy: 0.6025 - val_loss: 1.1350 - val_accuracy: 0.6873
# Epoch 8/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 1.2211 - accuracy: 0.6406 - val_loss: 1.0043 - val_accuracy: 0.7256
# Epoch 9/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 1.1074 - accuracy: 0.6717 - val_loss: 0.8898 - val_accuracy: 0.7762
# Epoch 10/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.9981 - accuracy: 0.7024 - val_loss: 0.8018 - val_accuracy: 0.7878
# Epoch 11/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.9168 - accuracy: 0.7278 - val_loss: 0.7311 - val_accuracy: 0.8000
# Epoch 12/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.8429 - accuracy: 0.7474 - val_loss: 0.6770 - val_accuracy: 0.8125
# Epoch 13/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.7777 - accuracy: 0.7680 - val_loss: 0.6270 - val_accuracy: 0.8299
# Epoch 14/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.7212 - accuracy: 0.7840 - val_loss: 0.5898 - val_accuracy: 0.8363
# Epoch 15/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.6751 - accuracy: 0.7988 - val_loss: 0.5482 - val_accuracy: 0.8472
# Epoch 16/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.6357 - accuracy: 0.8095 - val_loss: 0.5281 - val_accuracy: 0.8515
# Epoch 17/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.5941 - accuracy: 0.8228 - val_loss: 0.4824 - val_accuracy: 0.8685
# Epoch 18/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.5505 - accuracy: 0.8347 - val_loss: 0.4653 - val_accuracy: 0.8655
# Epoch 19/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.5264 - accuracy: 0.8452 - val_loss: 0.4449 - val_accuracy: 0.8707
# Epoch 20/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.5050 - accuracy: 0.8503 - val_loss: 0.4225 - val_accuracy: 0.8787
# Epoch 21/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.4721 - accuracy: 0.8606 - val_loss: 0.4042 - val_accuracy: 0.8844
# Epoch 22/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.4534 - accuracy: 0.8659 - val_loss: 0.3976 - val_accuracy: 0.8884
# Epoch 23/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.4270 - accuracy: 0.8758 - val_loss: 0.3769 - val_accuracy: 0.8893
# Epoch 24/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.4106 - accuracy: 0.8794 - val_loss: 0.3696 - val_accuracy: 0.8918
# Epoch 25/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.3922 - accuracy: 0.8850 - val_loss: 0.3596 - val_accuracy: 0.8950
# Epoch 26/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.3675 - accuracy: 0.8910 - val_loss: 0.3477 - val_accuracy: 0.8943
# Epoch 27/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.3567 - accuracy: 0.8949 - val_loss: 0.3317 - val_accuracy: 0.9009
# Epoch 28/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.3419 - accuracy: 0.8999 - val_loss: 0.3341 - val_accuracy: 0.9014
# Epoch 29/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.3264 - accuracy: 0.9036 - val_loss: 0.3155 - val_accuracy: 0.9045
# Epoch 30/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.3147 - accuracy: 0.9076 - val_loss: 0.3073 - val_accuracy: 0.9070
# Epoch 31/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.3042 - accuracy: 0.9117 - val_loss: 0.2998 - val_accuracy: 0.9079
# Epoch 32/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.2933 - accuracy: 0.9161 - val_loss: 0.3036 - val_accuracy: 0.9088
# Epoch 33/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.2790 - accuracy: 0.9188 - val_loss: 0.3001 - val_accuracy: 0.9095
# Epoch 34/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.2717 - accuracy: 0.9200 - val_loss: 0.2807 - val_accuracy: 0.9111
# Epoch 35/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.2613 - accuracy: 0.9236 - val_loss: 0.2717 - val_accuracy: 0.9168
# Epoch 36/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.2503 - accuracy: 0.9276 - val_loss: 0.2727 - val_accuracy: 0.9175
# Epoch 37/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.2464 - accuracy: 0.9285 - val_loss: 0.2647 - val_accuracy: 0.9186
# Epoch 38/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.2394 - accuracy: 0.9304 - val_loss: 0.2560 - val_accuracy: 0.9218
# Epoch 39/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.2295 - accuracy: 0.9345 - val_loss: 0.2515 - val_accuracy: 0.9222
# Epoch 40/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.2240 - accuracy: 0.9349 - val_loss: 0.2500 - val_accuracy: 0.9220
# Epoch 41/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.2138 - accuracy: 0.9368 - val_loss: 0.2453 - val_accuracy: 0.9231
# Epoch 42/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.2067 - accuracy: 0.9399 - val_loss: 0.2382 - val_accuracy: 0.9227
# Epoch 43/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.2035 - accuracy: 0.9416 - val_loss: 0.2421 - val_accuracy: 0.9222
# Epoch 44/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.1964 - accuracy: 0.9417 - val_loss: 0.2427 - val_accuracy: 0.9263
# Epoch 45/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.1918 - accuracy: 0.9442 - val_loss: 0.2324 - val_accuracy: 0.9265
# Epoch 46/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.1845 - accuracy: 0.9457 - val_loss: 0.2288 - val_accuracy: 0.9295
# Epoch 47/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.1823 - accuracy: 0.9471 - val_loss: 0.2280 - val_accuracy: 0.9313
# Epoch 48/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.1759 - accuracy: 0.9492 - val_loss: 0.2264 - val_accuracy: 0.9274
# Epoch 49/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.1690 - accuracy: 0.9499 - val_loss: 0.2196 - val_accuracy: 0.9324
# Epoch 50/50
# 34799/34799 [==============================] - 1s 23us/step - loss: 0.1643 - accuracy: 0.9528 - val_loss: 0.2068 - val_accuracy: 0.9374

# %%
score = model.evaluate(X_test_processed,y_test)
print('test accuracy',score[1])
# Out:
# 12630/12630 [==============================] - 1s 57us/step
# test accuracy 0.9163103699684143

# %%
history.history.keys()
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['training','valdaition'])
plt.title('training and validaition losses')
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['training','validation'])
plt.title('Training and validation accuracy')
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %%
prediction = model.predict_classes(X_test_processed)
y_trure_label=y_test

# %%
from sklearn.metrics import confusion_matrix
matrix = confusion_matrix(y_trure_label,prediction)
plt.figure(figsize=(20,20))
sns.heatmap(matrix,annot=True)

# %%
L=6
w=6
fig , axes = plt.subplots(L,w,figsize=(12,12))
axes = axes.ravel()
for i in range(0,L*w):
  axes[i].imshow(X_test[i])
  axes[i].set_title('prediction ={}\n true={}'.format(prediction[i],y_trure_label[i]))
  axes[i].axis('off')
plt.subplots_adjust(wspace=1)

# %%
model.save('My_model.h5')
